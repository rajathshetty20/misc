# %%
import qutip

# %%
b = qutip.Bloch()

b.add_vectors([
    [1,1,1],
    [1,0,0],
    [1,1,2],
])

b.add_vectors([
    [2,2,1],
    [2,1,2]
],['k','red'])

b.add_vectors([0,0,1],'grey')

b.show()

# %%
b.vector_color_specified
# Out:
# {3: 'k', 4: 'red', 5: 'grey'}
